# %% [markdown]
# <a href="https://colab.research.google.com/github/netcook-app2/notebook/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://i.ibb.co.com/X2QtRKS/2024-07-20-23-28-removebg-preview-1.png" width="400px" height="430px">

# %% [markdown]
# ## **Check Cookies Netflix simple usage and powerful. Good luck ✨**

# %%
# Install requirements

# !pip install netcook-notebook > /dev/null 2>&1

# %%
from netcook_notebook import checked_cookies, netflix_url

checked_cookies(netflix_url)
# Out:
# SCRIPT by. @NetCook
# app2.dn-project.biz.id
#
# Menu:
# 1. Check Cookies Netflix
# 2. Exit
#
# Enter your choice (1/2): 1
# Please upload a batch file (.zip) or a single file (.json or .txt):
#      <input type="file" id="files-a47ae05b-7dbc-43fb-9daa-6ab64cd52011" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a47ae05b-7dbc-43fb-9daa-6ab64cd52011">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# ...
